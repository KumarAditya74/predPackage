# %%
import pandas as pd

# %%
df = pd.read_csv(r'data/Placements_Dataset.csv')
df.head()
# Out:
#          Name of Student  Roll No.  No. of DSA questions  CGPA Knows ML  \
# 0              Todd Pope     30678                   151  8.52      Yes
# 1           Sandra Brown     49191                    24  1.23      Yes
# 2  Mrs. Amanda Singleton     83519                   333  9.85       No
# 3       Matthew Alvarado     56203                   132  1.96       No
# 4        Christine Smith     82173                   198  9.73      Yes
#
#   Knows DSA Knows Python Knows JavaScript Knows HTML Knows CSS Knows Cricket  \
# 0       Yes          Yes              Yes         No       Yes            No
# 1        No           No              Yes         No        No           Yes
# 2       Yes          Yes               No        Yes        No            No
# 3        No          Yes               No        Yes        No            No
# 4       Yes          Yes              Yes        Yes       Yes           Yes
#
#   Knows Dance Participated in College Fest Was in Coding Club  \
# ...

# %%
df.isnull()
# Out:
#         Name of Student  Roll No.  No. of DSA questions   CGPA  Knows ML  \
# 0                 False     False                 False  False     False
# 1                 False     False                 False  False     False
# 2                 False     False                 False  False     False
# 3                 False     False                 False  False     False
# 4                 False     False                 False  False     False
# ...                 ...       ...                   ...    ...       ...
# 219995            False     False                 False  False     False
# 219996            False     False                 False  False     False
# 219997            False     False                 False  False     False
# 219998            False     False                 False  False     False
# 219999            False     False                 False  False     False
#
#         Knows DSA  Knows Python  Knows JavaScript  Knows HTML  Knows CSS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220000 entries, 0 to 219999
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name of Student               220000 non-null  object
#  1   Roll No.                      220000 non-null  int64
#  2   No. of DSA questions          220000 non-null  int64
#  3   CGPA                          220000 non-null  float64
#  4   Knows ML                      215581 non-null  object
#  5   Knows DSA                     220000 non-null  object
#  6   Knows Python                  215573 non-null  object
#  7   Knows JavaScript              215718 non-null  object
#  8   Knows HTML                    215671 non-null  object
#  9   Knows CSS                     215678 non-null  object
#  10  Knows Cricket                 220000 non-null  object
#  11  Knows Dance                   220000 non-null  object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = {'Category': ['Name of Student', 'Roll No.', 'No. of DSA questions', 'CGPA', 'Knows ML', 'Knows DSA', 'Knows Python', 'Knows JavaScript',
                     'Knows HTML','Knows CSS','Knows Cricket','Knows Dance','Participated in College Fest','Was in Coding Club'
                     'No. of backlogs','Interview Room Temperature','Age of Candidate','Branch of Engineering','Placement Package'
                     
                     ]}
df = pd.DataFrame(data)

# Calculate percentage occurrence
percentages = df['Category'].value_counts(normalize=True) * 100

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage Occurrence of Columns')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df.drop(columns='Name of Student', axis = 1, inplace = True)
df.drop(columns='Roll No.', axis = 1, inplace = True)
df.drop(columns='Branch of Engineering', axis = 1, inplace = True)
df.drop(columns=['Interview Room Temperature','Age of Candidate','Knows Cricket','Knows Dance','Participated in College Fest','Knows HTML','Knows CSS'],inplace=True)

# %%
X = df.drop(labels='Placement Package', axis = 1)

Y = df['Placement Package']
